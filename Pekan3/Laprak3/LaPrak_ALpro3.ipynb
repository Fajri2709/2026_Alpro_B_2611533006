# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA DAN PEMOGRAMAN**
#
# **“OPERATOR PADA PYHTON”**
#
# **Disusun Oleh :**
#
# **Fajri Ramadhan**
#
# **2611533006**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo_unand.png.jpeg" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur kita panjatkan ke hadirat Tuhan Yang Maha Esa karena atas rahmat dan karunia-Nya, laporan praktikum yang berjudul “Operator pada Python” ini dapat diselesaikan dengan baik.
#
# Laporan ini dibuat sebagai salah satu bentuk dokumentasi dari kegiatan praktikum pemrograman Python. Melalui praktikum ini, penulis mempelajari berbagai macam operator yang digunakan dalam bahasa pemrograman Python, mulai dari operator aritmatika, perbandingan, logika, penugasan, hingga operator lainnya yang sering digunakan dalam pembuatan program.
#
# Penulis menyadari bahwa laporan ini masih memiliki kekurangan, baik dari segi isi maupun penyusunan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan agar laporan ini dapat menjadi lebih baik di kemudian hari.
#
# Semoga laporan ini dapat memberikan manfaat dan membantu pembaca dalam memahami penggunaan operator pada Python, khususnya bagi yang baru mulai belajar pemrograman.
#
# Padang, 2026
#
# Fajri Ramadhan

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pada saat ini, pemrograman menjadi salah satu keterampilan yang banyak digunakan dalam bidang teknologi informasi. Salah satu bahasa pemrograman yang cukup populer dan mudah dipelajari adalah Python. Python banyak digunakan karena memiliki sintaks yang sederhana sehingga cocok digunakan oleh pemula maupun programmer yang sudah berpengalaman.
#
# Dalam membuat sebuah program, kita tidak hanya membutuhkan variabel dan tipe data, tetapi juga membutuhkan operator. Operator merupakan simbol atau kata tertentu yang digunakan untuk melakukan suatu operasi terhadap data atau nilai. Misalnya, tanda + digunakan untuk melakukan penjumlahan, tanda - untuk pengurangan, dan tanda == untuk membandingkan dua nilai.
#
# Operator memiliki peranan penting dalam pemrograman karena hampir setiap program membutuhkan proses perhitungan, perbandingan, maupun pengambilan keputusan. Dengan memahami operator, seseorang akan lebih mudah membuat program yang dapat melakukan proses sesuai dengan kebutuhan.
#
# Oleh karena itu, praktikum mengenai operator pada Python dilakukan agar mahasiswa atau praktikan dapat memahami jenis-jenis operator serta mengetahui cara menggunakannya dalam program sederhana.
#
# ## 1.2 Tujuan
# 1. Mengetahui pengertian dan fungsi operator dalam Python.
# 2. Mengenal berbagai jenis operator yang tersedia pada Python.
# 3. Memahami penggunaan operator aritmatika dalam melakukan perhitungan.
# 4. Memahami penggunaan operator perbandingan untuk membandingkan nilai.
# 5. Memahami penggunaan operator logika dalam pengambilan keputusan.
# 6. Mampu menggunakan operator penugasan dalam program Python.
# 7. Menerapkan berbagai operator dalam membuat program sederhana.
#
# ## 1.3 Manfaat
# 1. Menambah pemahaman mengenai dasar-dasar bahasa pemrograman Python.
# 2. Membantu praktikan memahami fungsi berbagai jenis operator.
# 3. Melatih kemampuan dalam menulis dan menjalankan kode Python.
# 4. Membantu praktikan dalam membuat program yang melibatkan perhitungan dan pengambilan keputusan.
# 5. Menjadi dasar untuk mempelajari materi pemrograman Python yang lebih lanjut.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# ## 2.1.1 Pengertian Operator
# Operator adalah simbol atau kata khusus yang digunakan untuk melakukan operasi terhadap satu atau lebih operand. Operand dapat berupa nilai, variabel, maupun objek. Dalam Python, operator digunakan untuk melakukan berbagai proses seperti perhitungan, perbandingan, penggabungan kondisi, hingga manipulasi nilai biner.
#
# Beberapa jenis operator yang digunakan dalam praktikum ini antara lain operator aritmatika, assignment, perbandingan, logika, membership, identity, dan bitwise.
#
# ## 2.1.2 Operator Aritmatika
# Operator aritmatika digunakan untuk melakukan operasi matematika. Beberapa operator aritmatika yang terdapat pada Python yaitu:
#
# Operator Fungsi
#
# Penjumlahan
# Pengurangan
# Perkalian / Pembagian // Pembagian bulat % Sisa pembagian atau modulus ** Perpangkatan
# Dalam program transaksi, operator aritmatika dapat digunakan untuk menghitung besar diskon, total pembayaran, rata-rata harga barang, dan sisa pembagian.
#
# ## 2.1.3 Operator Assignment
# Operator assignment digunakan untuk memberikan atau memperbarui nilai pada sebuah variabel. Operator dasar assignment adalah =. Python juga menyediakan augmented assignment, yaitu operator yang menggabungkan operasi aritmatika dengan assignment.
#
# Contohnya:
#
# nilai_3003 = 10 nilai_3003 += 5
#
# Setelah operasi tersebut, nilai nilai_3003 menjadi 15.
#
# Beberapa augmented assignment yang umum digunakan yaitu +=, -=, *=, /=, dan lainnya.
#
# ## 2.1.4 Operator Perbandingan
# Operator perbandingan digunakan untuk membandingkan dua nilai. Hasil dari operator perbandingan berupa nilai Boolean, yaitu True atau False.
#
# Beberapa operator perbandingan antara lain:
#
# Operator Fungsi == Sama dengan != Tidak sama dengan
#
# Lebih besar < Lebih kecil = Lebih besar atau sama dengan <= Lebih kecil atau sama dengan
#
# Dalam program transaksi, operator perbandingan digunakan untuk menentukan apakah total belanja telah mencapai batas minimum dan apakah jumlah barang telah memenuhi persyaratan.
#
# ## 2.1.5 Operator Logika
# Operator logika digunakan untuk menggabungkan atau membalik kondisi Boolean. Python memiliki tiga operator logika utama, yaitu and, or, dan not.
#
# and menghasilkan True jika seluruh kondisi bernilai True. or menghasilkan True jika setidaknya salah satu kondisi bernilai True. not membalik nilai Boolean.
#
# Contohnya:
#
# member_3003 = True belanja_3003 = True
#
# hasil_3003 = member_3003 and belanja_3003
#
# Hasil dari operasi tersebut adalah True.
#
# ## 2.1.6 Operator Membership
# Operator membership digunakan untuk memeriksa apakah suatu nilai terdapat di dalam suatu koleksi data seperti list, tuple, atau string.
#
# Operator membership yang digunakan dalam Python adalah:
#
# in not in
#
# Contohnya:
#
# kode_3003 = "HEMAT10" daftar_3003 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]
#
# hasil_3003 = kode_3003 in daftar_3003
#
# Hasilnya adalah True karena kode HEMAT10 terdapat di dalam daftar.
#
# ## 2.1.7 Operator Identity
# Operator identity digunakan untuk memeriksa apakah dua variabel merujuk pada objek yang sama.
#
# Operator identity terdiri dari:
#
# is is not
#
# Operator is membandingkan identitas objek, sedangkan == membandingkan nilai atau isi objek.
#
# Sebagai contoh, dua list dapat memiliki isi yang sama tetapi merupakan dua objek yang berbeda. Oleh karena itu, kedua list tersebut dapat menghasilkan True ketika dibandingkan dengan ==, tetapi False ketika dibandingkan menggunakan is.
#
# ## 2.1.8 Operator Bitwise
# Operator bitwise digunakan untuk melakukan operasi terhadap bilangan dalam representasi biner. Operator ini dapat digunakan untuk menggabungkan maupun memeriksa status tertentu yang direpresentasikan menggunakan bit.
#
# Beberapa operator bitwise yang digunakan dalam praktikum adalah:
#
# Operator Fungsi & AND bitwise | OR bitwise ^ XOR bitwise << Left shift
#
# Right shift
#
# Pada studi kasus transaksi, setiap kondisi pelanggan direpresentasikan menggunakan nilai bit:
#
# Nilai Bit Kondisi 0001 Pelanggan merupakan member 0010 Total belanja ≥ Rp200.000 0100 Jumlah barang ≥ 3 1000 Kode promo tersedia
#
# Operator OR digunakan untuk menggabungkan beberapa kondisi menjadi satu kode status. Operator AND digunakan untuk memeriksa kondisi tertentu dari kode status. Sementara itu, XOR dapat digunakan untuk membandingkan perbedaan antara kode transaksi dan kode referensi.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "aritmatika_2611533006"

# %%
# Buat file dengan nama arimatika_NIM.py
# Buat program untuk operator aritmatika dalam Python
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

angka1_3006 = int(input("input angka-1: "))
angka2_3006 = int(input("input angka-2: "))

# Penjumlahan
hasil_3006 = angka1_3006 + angka2_3006
print("\nOperator Penjumlahan")
print("Hasil =", hasil_3006)

# Pengurangan
hasil_3006 = angka1_3006 - angka2_3006
print("\nOperator Pengurangan")
print("Hasil =", hasil_3006)

# Perkalian
hasil_3006 = angka1_3006 * angka2_3006
print("\nOperator Perkalian")
print("Hasil =", hasil_3006)

# Pembagian, pembagian bulat, dan sisa bagi
if angka2_3006 != 0:
    hasil_3006 = angka1_3006 / angka2_3006
    print("\nOperator Pembagian")
    print("Hasil =", hasil_3006)

    hasil_3006 = angka1_3006 // angka2_3006
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil_3006)

    hasil_3006 = angka1_3006 % angka2_3006
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil_3006)
else:
    print("Angka kedua tidak boleh bernilai 0.")

# Pangkat
hasil_3006 = angka1_3006 ** angka2_3006
print("\nOperator Pangkat")
print("Hasil =", hasil_3006)
# Out:
# Operator Penjumlahan
# Hasil = 10
#
# Operator Pengurangan
# Hasil = -2
#
# Operator Perkalian
# Hasil = 24
#
# Operator Pembagian
# Hasil = 0.6666666666666666
#
# Operator Pembagian Bulat
# Hasil = 0
#
# Operator Sisa Bagi
# Hasil = 4
#
# Operator Pangkat
# Hasil = 4096

# %% [markdown]
# **Penjelasan :**
# 1. Bagian 1 sampai 2 berfungsi untuk membuat variabel `angka1_3006` dan `angka2_3006` yang digunakan untuk menyimpan dua bilangan yang dimasukkan oleh pengguna. Fungsi int(input()) digunakan untuk menerima input dalam bentuk bilangan bulat.
# 2. Bagian 4 sampai 6 berfungsi untuk melakukan operasi penjumlahan menggunakan operator +. Hasil penjumlahan dari `angka1_3006` dan `angka2_3006` disimpan ke dalam variabel `hasil_3006`, kemudian ditampilkan menggunakan fungsi print().
# 3. Bagian 8 sampai 10 berfungsi untuk melakukan operasi pengurangan menggunakan operator -. Nilai `angka2_3006` dikurangi dari `angka1_3006`, kemudian hasilnya disimpan ke dalam variabel `hasil_3006` dan ditampilkan ke layar.
# 4. Bagian 12 sampai 14 berfungsi untuk melakukan operasi perkalian menggunakan operator *. Nilai `angka1_3006` dikalikan dengan `angka2_3006`, kemudian hasilnya disimpan ke dalam variabel `hasil_3006` dan ditampilkan.
# 5. Bagian 16 sampai 17 berfungsi untuk melakukan pengecekan menggunakan operator perbandingan !=. Kondisi tersebut digunakan untuk memastikan bahwa `angka2_3006` tidak bernilai 0 sebelum dilakukan operasi pembagian.
# 6. Bagian 18 sampai 20 berfungsi untuk melakukan operasi pembagian menggunakan operator /. Nilai `angka1_3006` dibagi dengan `angka2_3006`, kemudian hasilnya disimpan ke dalam variabel `hasil_3006` dan ditampilkan.
# 7. Bagian 22 sampai 24 berfungsi untuk melakukan operasi pembagian bulat menggunakan operator //. Operator tersebut menghasilkan hasil pembagian tanpa menyertakan bagian desimal, kemudian hasilnya ditampilkan.
# 8. Bagian 26 sampai 28 berfungsi untuk melakukan operasi sisa bagi atau modulus menggunakan operator %. Operator tersebut digunakan untuk mendapatkan sisa hasil pembagian antara `angka1_3006` dan `angka2_3006`.
# 9. Bagian 29 sampai 30 berfungsi untuk memberikan pesan kepada pengguna apabila `angka2_3006` bernilai 0. Hal ini dilakukan karena angka 0 tidak dapat digunakan sebagai pembagi.
# 10. Bagian 32 sampai 34 berfungsi untuk melakukan operasi perpangkatan menggunakan operator **. Nilai `angka1_3006` dipangkatkan dengan `angka2_3006`, kemudian hasilnya disimpan ke dalam variabel `hasil_3006` dan ditampilkan ke layar.

# %% [markdown]
# ### 2.2.2 Program "assigment_2611533006"

# %%
# Buat file dengan nama assignment_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assignment dalam Python

angka1_3006 = int(input("Input angka-1: "))
angka2_3006 = int(input("Input angka-2: "))

print("\nNilai awal angka1 =", angka1_3006)
print("Nilai angka2 =", angka2_3006)

# Assignment biasa
hasil_3006 = angka1_3006
print("\nAssignment biasa (=)")
print("Hasil =", hasil_3006)

# Assignment penambahan
hasil_3006 = angka1_3006
hasil_3006 += angka2_3006
print("\nAssignment penambahan (+=)")
print("Hasil =", hasil_3006)

# Assignment pengurangan
hasil_3006 = angka1_3006
hasil_3006 -= angka2_3006
print("\nAssignment pengurangan (-=)")
print("Hasil =", hasil_3006)

# Assignment perkalian
hasil_3006 = angka1_3006
hasil_3006 *= angka2_3006
print("\nAssignment perkalian (*=)")
print("Hasil =", hasil_3006)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_3006 != 0:
    hasil_3006 = angka1_3006
    hasil_3006 /= angka2_3006
    print("\nAssignment pembagian (/=)")
    print("Hasil =", hasil_3006)
    
    # Operator tambahan
    hasil_3006 = angka1_3006
    hasil_3006 //= angka2_3006
    print("\nAssignment pembagian bulat (//=)")
    print("Hasil =", hasil_3006)
    
    hasil_3006 = angka1_3006
    hasil_3006 %= angka2_3006
    print("\nAssignment sisa bagi (%=)")
    print("Hasil =", hasil_3006)
else:
    print("\nPembagian tidak dapat dilakukan.")
    print("Angka kedua tidak boleh bernilai 0.")

# Operator tambahan: assignment perpangkatan
hasil_3006 = angka1_3006
hasil_3006 **= angka2_3006
print("\nAssignment perpangkatan (**=)")
print("Hasil =", hasil_3006)
# Out:
# Nilai awal angka1 = 6
# Nilai angka2 = 8
#
# Assignment biasa (=)
# Hasil = 6
#
# Assignment penambahan (+=)
# Hasil = 14
#
# Assignment pengurangan (-=)
# Hasil = -2
#
# Assignment perkalian (*=)
# Hasil = 48
#
# Assignment pembagian (/=)
# Hasil = 0.75
#
# Assignment pembagian bulat (//=)
# Hasil = 0
#
# Assignment sisa bagi (%=)
# Hasil = 6
#
# Assignment perpangkatan (**=)
# Hasil = 1679616

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 5** berfungsi untuk menerima dua angka dari pengguna dan menampilkan nilai awal dari variabel `angka1_3006` dan `angka2_3006`.
# 2. **Bagian 7 sampai 10** berfungsi untuk melakukan assignment biasa menggunakan operator `=` dengan menyimpan nilai `angka1_3006` ke dalam variabel `hasil_3006`, kemudian menampilkan hasilnya.
# 3. **Bagian 12 sampai 16** berfungsi untuk melakukan assignment penambahan menggunakan operator `+=`, yaitu menambahkan nilai `angka2_3006` ke dalam nilai `hasil_3006`.
# 4. **Bagian 18 sampai 22** berfungsi untuk melakukan assignment pengurangan menggunakan operator `-=`, yaitu mengurangi nilai `hasil_3006` dengan nilai `angka2_3006`.
# 5. **Bagian 24 sampai 28** berfungsi untuk melakukan assignment perkalian menggunakan operator `*=`, yaitu mengalikan nilai `hasil_3006` dengan nilai `angka2_3006`.
# 6. **Bagian 30 sampai 31** berfungsi untuk menentukan kondisi pembagian dengan memeriksa apakah `angka2_3006` tidak sama dengan 0 menggunakan operator `!=`.
# 7. **Bagian 32 sampai 35** berfungsi untuk melakukan assignment pembagian menggunakan operator `/=`, yaitu membagi nilai `hasil_3006` dengan `angka2_3006` dan menampilkan hasilnya.
# 8. **Bagian 37 sampai 41** berfungsi untuk melakukan assignment pembagian bulat menggunakan operator `//=`, yaitu membagi nilai `hasil_3006` dengan `angka2_3006` dan menghasilkan nilai pembagian tanpa angka desimal.
# 9. **Bagian 42 sampai 45** berfungsi untuk melakukan assignment sisa bagi menggunakan operator `%=`, yaitu mencari sisa hasil pembagian `hasil_3006` dengan `angka2_3006`.
# 10. **Bagian 46 sampai 48** berfungsi untuk menangani kondisi ketika `angka2_3006` bernilai 0. Program akan menampilkan pesan bahwa pembagian tidak dapat dilakukan.
# 11. **Bagian 50 sampai 54** berfungsi untuk melakukan assignment perpangkatan menggunakan operator `**=`, yaitu memangkatkan nilai `hasil_3006` dengan `angka2_3006` dan menampilkan hasilnya.

# %% [markdown]
# ### 2.2.3 Program "perbandingan_2611533006"

# %%
# Buat file dengan nama perbandingan_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator perbandingan dalam python

angka1_3006 = int(input("Input angka-1: "))
angka2_3006 = int(input("Input angka-2: "))

# Lebih besar dari
hasil_3006 = angka1_3006 > angka2_3006
print("\nOperator lebih besar dari")
print("angka1 > angka2 =", hasil_3006)

# Lebih kecil dari
hasil_3006 = angka1_3006 < angka2_3006
print("\nOperator lebih kecil dari")
print("angka1 < angka2 =", hasil_3006)

# Lebih besar dari atau sama dengan
hasil_3006 = angka1_3006 >= angka2_3006
print("\nOperator lebih besar dari atau sama dengan")
print("angka1 >= angka2 =", hasil_3006)

# Lebih kecil dari atau sama dengan
hasil_3006 = angka1_3006 <= angka2_3006
print("\nOperator lebih kecil dari atau sama dengan")
print("angka1 <= angka2 =", hasil_3006)

# Sama dengan
hasil_3006 = angka1_3006 == angka2_3006
print("\nOperator sama dengan")
print("angka1 == angka2 =", hasil_3006)

# Tidak sama dengan
hasil_3006 = angka1_3006 != angka2_3006
print("\nOperator tidak sama dengan")
print("angka1 != angka2 =", hasil_3006)

# Tambahan: perbandingan berantai dalam Python
hasil_3006 = 0 < angka1_3006 < 100
print("\nPerbadingan berantai")
print("0 < angka1 < 100 =", hasil_3006)

hasil_3006 = 0 < angka2_3006 < 100
print("o < angka2< 100 =", hasil_3006)
# Out:
# Operator lebih besar dari
# angka1 > angka2 = False
#
# Operator lebih kecil dari
# angka1 < angka2 = True
#
# Operator lebih besar dari atau sama dengan
# angka1 >= angka2 = False
#
# Operator lebih kecil dari atau sama dengan
# angka1 <= angka2 = True
#
# Operator sama dengan
# angka1 == angka2 = False
#
# Operator tidak sama dengan
# angka1 != angka2 = True
#
# Perbadingan berantai
# 0 < angka1 < 100 = True
# o < angka2< 100 = True

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 2** berfungsi untuk menerima dua angka dari pengguna dan menyimpannya ke dalam variabel `angka1_3006` dan `angka2_3006`.
# 2. **Bagian 4 sampai 7** berfungsi untuk membandingkan apakah `angka1_3006` lebih besar dari `angka2_3006` menggunakan operator `>` dan menampilkan hasil perbandingannya.
# 3. **Bagian 9 sampai 12** berfungsi untuk membandingkan apakah `angka1_3006` lebih kecil dari `angka2_3006` menggunakan operator `<` dan menampilkan hasilnya.
# 4. **Bagian 14 sampai 17** berfungsi untuk membandingkan apakah `angka1_3006` lebih besar dari atau sama dengan `angka2_3006` menggunakan operator `>=`.
# 5. **Bagian 19 sampai 22** berfungsi untuk membandingkan apakah `angka1_3006` lebih kecil dari atau sama dengan `angka2_3006` menggunakan operator `<=`.
# 6. **Bagian 24 sampai 27** berfungsi untuk membandingkan apakah `angka1_3006` sama dengan `angka2_3006` menggunakan operator `==`.
# 7. **Bagian 29 sampai 32** berfungsi untuk membandingkan apakah `angka1_3006` tidak sama dengan `angka2_3006` menggunakan operator `!=`.
# 8. **Bagian 34 sampai 37** berfungsi untuk melakukan perbandingan berantai dengan kondisi `0 < angka1_3006 < 100`, kemudian menyimpan dan menampilkan hasilnya.
# 9. **Bagian 38 sampai 40** berfungsi untuk melakukan perbandingan berantai dengan kondisi `0 < angka2_3006 < 100`, kemudian menyimpan dan menampilkan hasilnya.

# %% [markdown]
# ### 2.2.4 Program "logika_2611533006"

# %%
# Buat file dengan nama logika_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: a1_1234
# Program ini menggunakan fungsi input()
# Program operator logika dalam Python

# Memasukkan nilai booleam
# Input tidak peka terhadap huruf besar dan kecil
a1_3006 = input("Input nilai boolean-1 (true/false):").strip().lower() == "true"
a2_3006 = input("Input nilai boolean-2 (true/false):").strip().lower() == "true"

print("\nA1 =", a1_3006)
print("A2 =", a2_3006)

# Konjungsi: bernilai True jika keduanya True
hasil = a1_3006 and a2_3006
print("\nKonjungsi (AND)")
print("A1 and A2 =", hasil)

# Disjungsi: bernilai True jika salah satunya True
hasil_3006 = a1_3006 or a2_3006
print("\nDisjungsi (OR)")
print("A1 or A2 =", hasil_3006)

# Negasi A1: membalik nilai A1
hasil_3006 = not a1_3006
print("\nNegasi A1 (NOT)")
print("not A1 =", hasil_3006)

# Negasi A2: membalik nilai A2
hasil_3006 = not a2_3006
print("\nNegasi A2 (NOT)")
print("not A2 =", hasil_3006)

# XOR: bernilai True jika kedua nilai berbeda
hasil_3006 = a1_3006 != a2_3006
print("\nDisjungsi EKsklusif (XOR)")
print("A1 XOR A2 =", hasil_3006)
# Out:
# A1 = True
# A2 = False
#
# Konjungsi (AND)
# A1 and A2 = False
#
# Disjungsi (OR)
# A1 or A2 = True
#
# Negasi A1 (NOT)
# not A1 = False
#
# Negasi A2 (NOT)
# not A2 = True
#
# Disjungsi EKsklusif (XOR)
# A1 XOR A2 = True

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 5** berfungsi untuk menerima dua nilai boolean dari pengguna, mengubah input menjadi nilai `True` atau `False`, kemudian menampilkan nilai dari `a1_3006` dan `a2_3006`.
# 2. **Bagian 7 sampai 10** berfungsi untuk melakukan operasi konjungsi menggunakan operator `and`. Hasil akan bernilai `True` apabila kedua nilai `a1_3006` dan `a2_3006` bernilai `True`.
# 3. **Bagian 12 sampai 15** berfungsi untuk melakukan operasi disjungsi menggunakan operator `or`. Hasil akan bernilai `True` apabila salah satu atau kedua nilai bernilai `True`.
# 4. **Bagian 17 sampai 20** berfungsi untuk melakukan operasi negasi terhadap nilai `a1_3006` menggunakan operator `not`, sehingga nilai `True` akan menjadi `False` dan sebaliknya.
# 5. **Bagian 22 sampai 25** berfungsi untuk melakukan operasi negasi terhadap nilai `a2_3006` menggunakan operator `not`, sehingga nilai boolean yang dimasukkan akan dibalik.
# 6. **Bagian 27 sampai 30** berfungsi untuk melakukan operasi XOR atau disjungsi eksklusif dengan membandingkan `a1_3006` dan `a2_3006` menggunakan operator `!=`. Hasil akan bernilai `True` apabila kedua nilai boolean berbeda.

# %% [markdown]
# ### 2.2.5 Program "lainnya_2611533006"

# %%
# Buat file dengan nama lainnya_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Program operator keanggotaan dan Identitas

print("==================================")
print("1. OPERATOR KEANGGOTAAN")
print("==================================")

# Input beberapa data yang dipisahkan dengan koma
input_data_3006 = input("Masukkan beberapa angka, pisahkan dengan koma: ")

# Mengubah input menjadi list integer
data_3006 = [int(angka.strip()) for angka in input_data_3006.split(",")]

nilai_dicari_3006 = int(input("Masukkan angka yang ingin dicari: "))

# Operator In
hasil_3006 = nilai_dicari_3006 in data_3006
print("\nOperator keanggotaan IN")
print(nilai_dicari_3006, "in", data_3006, "=", hasil_3006)

# Operator Not In
hasil_3006 = nilai_dicari_3006 not in data_3006
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_3006, "not in", data_3006, "=", hasil_3006)

print("\n==================================")
print("2. OPERATOR IDENTITAS")
print("==================================")

# objek1 menggunakan list dari input pengguna
objek1_3006 = data_3006

# objek2 menggunakan list dari input pengguna
objek2_3006 = objek1_3006

# objek3 memiliki isi sama, tetapi merupakan objek baru
objek3_3006 = data_3006.copy()

print("objek1_3006 =", objek1_3006)
print("objek2_3006 =", objek2_3006)
print("objek3_3006 =", objek3_3006)

# Operator Is
hasil_3006 = objek1_3006 is objek2_3006
print("\nOperator identitas IS")
print("objek1_3006 is objek2_3006 =", hasil_3006)

# Operator Is Not
hasil_3006 = objek1_3006 is not objek3_3006
print("\nOperator identitas IS NOT")
print("objek1_3006 is not objek3_3006 =", hasil_3006)

# Membandingkan identitas dan nilai
print("\nMembandingkan identitas dan nilai:")
print("objek1_3006 is objek3_3006 =", objek1_3006 is objek3_3006)
print("objek1_3006 == objek3_3006 =", objek1_3006 == objek3_3006)
# Out:
# ...
# 1. OPERATOR KEANGGOTAAN
# ...
#
# Operator keanggotaan IN
# 5 in [15] = False
#
# Operator keanggotaan NOT IN
# 5 not in [15] = True
#
# ...
# 2. OPERATOR IDENTITAS
# ...
# objek1_3006 = [15]
# objek2_3006 = [15]
# objek3_3006 = [15]
#
# Operator identitas IS
# objek1_3006 is objek2_3006 = True
#
# Operator identitas IS NOT
# objek1_3006 is not objek3_3006 = True
#
# Membandingkan identitas dan nilai:
# objek1_3006 is objek3_3006 = False
# objek1_3006 == objek3_3006 = True

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 3** berfungsi untuk menampilkan judul program mengenai operator keanggotaan.
# 2. **Bagian 5 sampai 6** berfungsi untuk menerima beberapa angka dari pengguna yang dipisahkan dengan tanda koma dan menyimpannya ke dalam variabel `input_data_3006`.
# 3. **Bagian 8 sampai 8** berfungsi untuk mengubah data yang dimasukkan pengguna menjadi list berisi bilangan integer. Fungsi `split(",")` digunakan untuk memisahkan data berdasarkan koma, sedangkan `strip()` digunakan untuk menghilangkan spasi.
# 4. **Bagian 10 sampai 10** berfungsi untuk menerima angka yang ingin dicari oleh pengguna dan menyimpannya ke dalam variabel `nilai_dicari_3006`.
# 5. **Bagian 12 sampai 15** berfungsi untuk menggunakan operator keanggotaan `in` untuk memeriksa apakah `nilai_dicari_3006` terdapat di dalam `data_3006`, kemudian menampilkan hasil pemeriksaannya.
# 6. **Bagian 17 sampai 20** berfungsi untuk menggunakan operator keanggotaan `not in` untuk memeriksa apakah `nilai_dicari_3006` tidak terdapat di dalam `data_3006`, kemudian menampilkan hasilnya.
# 7. **Bagian 22 sampai 24** berfungsi untuk menampilkan judul bagian operator identitas.
# 8. **Bagian 26 sampai 27** berfungsi untuk membuat `objek1_3006` yang merujuk pada list `data_3006`.
# 9. **Bagian 29 sampai 30** berfungsi untuk membuat `objek2_3006` yang merujuk pada objek yang sama dengan `objek1_3006`.
# 10. **Bagian 32 sampai 33** berfungsi untuk membuat `objek3_3006` sebagai objek list baru dengan isi yang sama seperti `data_3006` menggunakan fungsi `copy()`.
# 11. **Bagian 35 sampai 37** berfungsi untuk menampilkan nilai dari `objek1_3006`, `objek2_3006`, dan `objek3_3006`.
# 12. **Bagian 39 sampai 42** berfungsi untuk menggunakan operator identitas `is` untuk memeriksa apakah `objek1_3006` dan `objek2_3006` merupakan objek yang sama, kemudian menampilkan hasilnya.
# 13. **Bagian 44 sampai 47** berfungsi untuk menggunakan operator identitas `is not` untuk memeriksa apakah `objek1_3006` dan `objek3_3006` merupakan objek yang berbeda, kemudian menampilkan hasilnya.
# 14. **Bagian 49 sampai 52** berfungsi untuk membandingkan identitas dan nilai dari `objek1_3006` dan `objek3_3006`. Operator `is` digunakan untuk membandingkan identitas objek, sedangkan operator `==` digunakan untuk membandingkan isi atau nilai kedua objek.

# %% [markdown]
# ### 2.2.6 Program "bitwise_2611533006"

# %%
# Buat file dengan nama bitwise_NIM.py
# Nama variabel ditambah 4 digit terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()

print("\n==================================")
print("3. OPERATOR BITWISE")
print("==================================")

angka1_3006 = int(input("Masukkan angka bitwise-1: "))
angka2_3006 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner:")
print("Angka 1:", angka1_3006, "-| biner", bin(angka1_3006))
print("Angka 2:", angka2_3006, "-| biner", bin(angka2_3006))

# Bitwise AND
hasil_3006 = angka1_3006 & angka2_3006
print("\nBitwise AND (&)")
print(angka1_3006, "&", angka2_3006, "=", hasil_3006)
print("Biner hasil =", bin(hasil_3006))
print("Biner hasil (8 bit) =", format(hasil_3006, '08b'))

# Bitwise OR
hasil_3006 = angka1_3006 | angka2_3006
print("\nBitwise OR (|)")
print(angka1_3006, "|", angka2_3006, "=", hasil_3006)
print("Biner hasil =", bin(hasil_3006))
print("Biner hasil (8 bit) =", format(hasil_3006, '08b'))

# Bitwise XOR
hasil_3006 = angka1_3006 ^ angka2_3006
print("\nBitwise XOR (^)")
print(angka1_3006, "^", angka2_3006, "=", hasil_3006)
print("Biner hasil =", bin(hasil_3006))
print("Biner hasil (8 bit) =", format(hasil_3006, '08b'))

# Bitwise NOT
hasil_3006 = ~angka1_3006
print("\nBitwise NOT (~)")
print("~", angka1_3006, "=", hasil_3006)
print("Biner hasil =", bin(hasil_3006))
print("Biner hasil (8 bit) =", format(hasil_3006, '08b'))

# Bitwise geser kiri
jumlah_geser_3006 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_3006 = angka1_3006 << jumlah_geser_3006
print("\nBitwise Geser Kiri (<<)")
print(angka1_3006, "<<", jumlah_geser_3006, "=", hasil_3006)
print("Biner hasil =", bin(hasil_3006))
print("Biner hasil (8 bit) =", format(hasil_3006, '08b'))

# Bitwise geser kanan
hasil_3006 = angka1_3006 >> jumlah_geser_3006
print("\nBitwise Geser Kanan (>>)")
print(angka1_3006, ">>", jumlah_geser_3006, "=", hasil_3006)
print("Biner hasil =", bin(hasil_3006))
print("Biner hasil (8 bit) =", format(hasil_3006, '08b'))
# Out:
# ...
# 3. OPERATOR BITWISE
# ...
#
# Angka dalam bentuk desimal dan biner:
# Angka 1: 53 -| biner 0b110101
# Angka 2: 48 -| biner 0b110000
#
# Bitwise AND (&)
# 53 & 48 = 48
# Biner hasil = 0b110000
# Biner hasil (8 bit) = 00110000
#
# Bitwise OR (|)
# 53 | 48 = 53
# Biner hasil = 0b110101
# Biner hasil (8 bit) = 00110101
#
# Bitwise XOR (^)
# 53 ^ 48 = 5
# Biner hasil = 0b101
# Biner hasil (8 bit) = 00000101
#
# Bitwise NOT (~)
# ~ 53 = -54
# Biner hasil = -0b110110
# Biner hasil (8 bit) = -0110110
#
# Bitwise Geser Kiri (<<)
# 53 << 2 = 212
# Biner hasil = 0b11010100
# Biner hasil (8 bit) = 11010100
#
# Bitwise Geser Kanan (>>)
# 53 >> 2 = 13
# Biner hasil = 0b1101
# Biner hasil (8 bit) = 00001101

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 3** berfungsi untuk menampilkan judul program yang menunjukkan bahwa kode membahas operator bitwise.
# 2. **Bagian 5 sampai 6** berfungsi untuk menerima dua angka dari pengguna yang akan digunakan dalam operasi bitwise.
# 3. **Bagian 8 sampai 10** berfungsi untuk menampilkan nilai kedua angka dalam bentuk desimal dan biner menggunakan fungsi `bin()`.
# 4. **Bagian 12 sampai 17** berfungsi untuk melakukan operasi Bitwise AND menggunakan operator `&`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
# 5. **Bagian 19 sampai 24** berfungsi untuk melakukan operasi Bitwise OR menggunakan operator `|`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
# 6. **Bagian 26 sampai 31** berfungsi untuk melakukan operasi Bitwise XOR menggunakan operator `^`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
# 7. **Bagian 33 sampai 38** berfungsi untuk melakukan operasi Bitwise NOT menggunakan operator `~` terhadap `angka1_3006`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
# 8. **Bagian 40 sampai 41** berfungsi untuk menentukan dan menerima jumlah pergeseran bit dari pengguna yang akan digunakan dalam operasi Bitwise geser kiri dan geser kanan.
# 9. **Bagian 43 sampai 47** berfungsi untuk melakukan operasi Bitwise geser kiri menggunakan operator `<<`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
# 10. **Bagian 49 sampai 54** berfungsi untuk melakukan operasi Bitwise geser kanan menggunakan operator `>>`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# Studi Kasus: Sistem Simulasi Transaksi dan Validasi Akses Toko
# Anda diminta untuk membuat sebuah program kasir sederhana yang digunakan untuk menghitung total transaksi pelanggan sekaligus melakukan pemeriksaan terhadap status pelanggan dan hak akses terhadap promo tertentu. Program menerima data transaksi dan informasi pelanggan, kemudian menggunakan berbagai jenis operator Python untuk menentukan total pembayaran, status diskon, kelayakan promo, serta hak akses pelanggan. Seluruh proses harus dibuat dalam satu alur program yang utuh.

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas3_2611533006"

# %%
print("=== SISTEM TRANSAKSI TOKO ===")

nama_3006 = input("Masukkan Nama Pelanggan : ")
status_3006 = input("Masukkan Status Pelanggan (member/nonmember) : ").lower()
total_belanja_3006 = float(input("Masukkan Total Belanja : Rp"))
jumlah_barang_3006 = int(input("Masukkan Jumlah Barang : "))
kode_promo_3006 = input("Masukkan Kode Promo : ").upper()

syarat_belanja_3006 = total_belanja_3006 >= 200000
syarat_barang_3006 = jumlah_barang_3006 >= 3
status_member_3006 = status_3006 == "member"

daftar_promo_3006 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

promo_tersedia_3006 = kode_promo_3006 in daftar_promo_3006
promo_tidak_tersedia_3006 = kode_promo_3006 not in daftar_promo_3006

diskon_member_3006 = status_member_3006 and syarat_belanja_3006

promo_didapatkan_3006 = promo_tersedia_3006 and (syarat_belanja_3006 or syarat_barang_3006)

bukan_member_3006 = not status_member_3006

if diskon_member_3006:
    persentase_diskon_3006 = 0.10
else:
    persentase_diskon_3006 = 0.05 if syarat_belanja_3006 else 0

besar_diskon_3006 = total_belanja_3006 * persentase_diskon_3006

total_pembayaran_3006 = total_belanja_3006 - besar_diskon_3006

if jumlah_barang_3006 > 0:
    rata_rata_barang_3006 = total_belanja_3006 / jumlah_barang_3006
else:
    rata_rata_barang_3006 = 0

sisa_pembagian_3006 = int(total_belanja_3006) % jumlah_barang_3006 if jumlah_barang_3006 > 0 else 0


poin_3006 = 0
if status_member_3006:
    poin_3006 += int(total_pembayaran_3006 // 10000)

jumlah_barang_tersisa_3006 = jumlah_barang_3006
if promo_didapatkan_3006:
    jumlah_barang_tersisa_3006 -= 1

kode_1_3006 = ["HEMAT10"]
kode_2_3006 = ["HEMAT10"]

nilai_sama_3006 = kode_1_3006 == kode_2_3006
objek_sama_3006 = kode_1_3006 is kode_2_3006
objek_berbeda_3006 = kode_1_3006 is not kode_2_3006


kode_member_3006 = 1 if status_member_3006 else 0
kode_belanja_3006 = 2 if syarat_belanja_3006 else 0
kode_barang_3006 = 4 if syarat_barang_3006 else 0
kode_promo_3006 = 8 if promo_tersedia_3006 else 0

# Operator OR (|)
kode_status_3006 = (
    kode_member_3006
    | kode_belanja_3006
    | kode_barang_3006
    | kode_promo_3006
)

cek_member_3006 = kode_status_3006 & 1
cek_belanja_3006 = kode_status_3006 & 2
cek_barang_3006 = kode_status_3006 & 4
cek_promo_3006 = kode_status_3006 & 8

kode_referensi_3006 = 11
perbandingan_status_3006 = kode_status_3006 ^ kode_referensi_3006

kode_shift_3006 = kode_status_3006 << 1


member_access_3006 = bool(cek_member_3006)
promo_access_3006 = bool(cek_promo_3006)
free_shipping_access_3006 = syarat_belanja_3006 and syarat_barang_3006


print("\n=== DATA PELANGGAN ===")
print("Nama Pelanggan       :", nama_3006)
print("Status Pelanggan     :", status_3006)
print("Total Belanja        : Rp", total_belanja_3006)
print("Jumlah Barang        :", jumlah_barang_3006)
print("Kode Promo           :", kode_promo_3006)


print("\n=== HASIL VALIDASI ===")
print("Belanja >= Rp200000  :", syarat_belanja_3006)
print("Jumlah Barang >= 3   :", syarat_barang_3006)
print("Status Member        :", status_member_3006)
print("Kode Promo Tersedia  :", promo_tersedia_3006)
print("Mendapatkan Diskon   :", diskon_member_3006)
print("Mendapatkan Promo    :", promo_didapatkan_3006)


print("\n=== HASIL PERHITUNGAN ===")
print("Besarnya Diskon      : Rp", besar_diskon_3006)
print("Total Pembayaran     : Rp", total_pembayaran_3006)
print("Rata-rata Harga      : Rp", rata_rata_barang_3006)
print("Sisa Pembagian       :", sisa_pembagian_3006)


print("\n=== HAK AKSES PELANGGAN ===")
print("Kode Hak Akses       :", format(kode_status_3006, "04b"))
print("Member Access        :", member_access_3006)
print("Promo Access         :", promo_access_3006)
print("Free Shipping Access :", free_shipping_access_3006)
print("Poin Pelanggan       :", poin_3006)


print("\n=== OPERATOR IDENTITAS ===")
print("kode_1 == kode_2     :", nilai_sama_3006)
print("kode_1 is kode_2     :", objek_sama_3006)
print("kode_1 is not kode_2 :", objek_berbeda_3006)


print("\n=== OPERASI BITWISE ===")
print("Kode Status Transaksi")
print("0001 | 0010 | 0100 | 1000")

print("Kode Biner           :", format(kode_status_3006, "04b"))
print("Kode Desimal         :", kode_status_3006)

print("\n=== PEMERIKSAAN STATUS ===")

print("\nCek Member")
print(format(kode_status_3006, "04b"), "& 0001")
print("Hasil Biner         :", format(cek_member_3006, "04b"))
print("Hasil Desimal       :", cek_member_3006)

print("\nCek Belanja")
print(format(kode_status_3006, "04b"), "& 0010")
print("Hasil Biner         :", format(cek_belanja_3006, "04b"))
print("Hasil Desimal       :", cek_belanja_3006)

print("\nCek Jumlah Barang")
print(format(kode_status_3006, "04b"), "& 0100")
print("Hasil Biner         :", format(cek_barang_3006, "04b"))
print("Hasil Desimal       :", cek_barang_3006)

print("\nCek Promo")
print(format(kode_status_3006, "04b"), "& 1000")
print("Hasil Biner         :", format(cek_promo_3006, "04b"))
print("Hasil Desimal       :", cek_promo_3006)

print("\n=== PERBANDINGAN STATUS (XOR) ===")
print("Kode Transaksi      :", format(kode_status_3006, "04b"))
print("Kode Referensi      :", format(kode_referensi_3006, "04b"))
print(format(kode_status_3006, "04b"), "^",
      format(kode_referensi_3006, "04b"))
print("Hasil Biner         :", format(perbandingan_status_3006, "04b"))
print("Hasil Desimal       :", perbandingan_status_3006)

print("\n=== SHIFT ===")
print(format(kode_status_3006, "04b"), "<< 1")
print("Hasil Biner         :", format(kode_shift_3006, "b"))
print("Hasil Desimal       :", kode_shift_3006)

print("\n=== SELESAI ===")
# Out:
# === SISTEM TRANSAKSI TOKO ===
#
# === DATA PELANGGAN ===
# Nama Pelanggan       : Fajri Ramadhan
# Status Pelanggan     : member
# Total Belanja        : Rp 500000.0
# Jumlah Barang        : 6
# Kode Promo           : 8
#
# === HASIL VALIDASI ===
# Belanja >= Rp200000  : True
# Jumlah Barang >= 3   : True
# Status Member        : True
# Kode Promo Tersedia  : True
# Mendapatkan Diskon   : True
# Mendapatkan Promo    : True
#
# === HASIL PERHITUNGAN ===
# Besarnya Diskon      : Rp 50000.0
# Total Pembayaran     : Rp 450000.0
# Rata-rata Harga      : Rp 83333.33333333333
# Sisa Pembagian       : 2
#
# === HAK AKSES PELANGGAN ===
# Kode Hak Akses       : 1111
# Member Access        : True
# Promo Access         : True
# Free Shipping Access : True
# Poin Pelanggan       : 45
#
# === OPERATOR IDENTITAS ===
# kode_1 == kode_2     : True
# kode_1 is kode_2     : False
# kode_1 is not kode_2 : True
#
# === OPERASI BITWISE ===
# Kode Status Transaksi
# 0001 | 0010 | 0100 | 1000
# ...

# %% [markdown]
# **Penjelasan :**
# 1. Jelaskan operator aritmatika apa saja yang digunakan dan bagaimana operator tersebut membantu menghitung transaksi.
#
# Program menggunakan beberapa operator aritmatika, yaitu perkalian (*) untuk menghitung besar diskon, pengurangan (-) untuk menghitung total pembayaran setelah diskon, pembagian (/) untuk menghitung rata-rata harga barang, pembagian bulat (//) untuk menghitung poin pelanggan, dan modulus (%) untuk mendapatkan sisa pembagian total belanja dengan jumlah barang. Operator tersebut digunakan agar perhitungan transaksi dapat dilakukan secara otomatis berdasarkan input pengguna.
#
# 2. Jelaskan perbedaan operator and, or, dan not berdasarkan penerapannya pada program.
#
# Operator and menghasilkan True apabila semua kondisi yang digabungkan bernilai True. Dalam program, and digunakan untuk menentukan apakah member yang memenuhi minimum belanja mendapatkan diskon. Operator or menghasilkan True apabila minimal salah satu kondisi bernilai True, misalnya ketika memeriksa syarat promo. Operator not digunakan untuk membalik nilai Boolean, contohnya not status_member_3006 menghasilkan True ketika pelanggan bukan member.
#
# 3. Jelaskan fungsi operator in dan not in pada pemeriksaan kode promo.
#
# Operator in digunakan untuk memeriksa apakah suatu kode promo terdapat di dalam daftar promo yang tersedia. Jika kode ditemukan, hasilnya True. Sebaliknya, not in digunakan untuk memeriksa apakah kode promo tidak terdapat dalam daftar. Contohnya, HEMAT10 in daftar_promo_3006 menghasilkan True.
#
# 4. Apa perbedaan antara is dan == pada Python?
#
# == digunakan untuk membandingkan nilai atau isi dari dua objek, sedangkan is digunakan untuk membandingkan identitas objek, yaitu apakah dua variabel menunjuk pada objek yang sama. Pada program, dua list dapat mempunyai isi yang sama sehingga == bernilai True, tetapi tetap merupakan objek yang berbeda sehingga is bernilai False.
#
# 5. Jelaskan bagaimana operator bitwise digunakan untuk menentukan hak akses pelanggan.
#
# Setiap kondisi pelanggan direpresentasikan dengan satu bit. 0001 menunjukkan member, 0010 menunjukkan belanja minimal Rp200.000, 0100 menunjukkan jumlah barang minimal 3, dan 1000 menunjukkan kode promo tersedia. Operator OR (|) digunakan untuk menggabungkan kondisi tersebut menjadi satu kode status. Operator AND (&) digunakan untuk memeriksa bit tertentu sehingga hak akses pelanggan dapat diketahui. Operator XOR (^) digunakan untuk membandingkan kode transaksi dengan kode referensi.
#
# 6. Jelaskan alur program mulai dari input hingga menghasilkan total pembayaran dan status promo.
#
# Program dimulai dengan meminta nama, status pelanggan, total belanja, jumlah barang, dan kode promo. Data tersebut kemudian digunakan untuk melakukan perbandingan terhadap syarat minimum belanja, jumlah barang, status member, dan ketersediaan promo. Kondisi-kondisi tersebut digabungkan menggunakan operator logika untuk menentukan diskon dan promo. Setelah itu program menghitung besar diskon, total pembayaran, rata-rata harga barang, dan poin pelanggan. Selanjutnya kondisi pelanggan diubah menjadi kode bitwise untuk menentukan hak akses dan menampilkan hasil seluruh operator.
#
# 7. Identifikasi minimal satu kondisi dalam program yang menghasilkan True dan satu kondisi yang menghasilkan False.
#
# Contoh kondisi True adalah:
#
# total_belanja_3006 >= 200000
#
# jika total belanja Rp250.000, hasilnya True.
#
# Contoh kondisi False adalah:
#
# jumlah_barang_3006 >= 3
#
# jika pelanggan membeli 2 barang, hasilnya False.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa operator merupakan salah satu bagian penting dalam pemrograman Python yang digunakan untuk melakukan berbagai operasi terhadap data. Dengan menggunakan operator, program dapat melakukan perhitungan, membandingkan nilai, menentukan kondisi, memberikan nilai pada variabel, serta melakukan operasi lainnya sesuai dengan kebutuhan.
#
# Dalam Python terdapat beberapa jenis operator, seperti operator aritmatika, operator perbandingan, operator logika, operator penugasan, operator identitas, operator keanggotaan, dan operator bitwise. Setiap operator memiliki fungsi dan cara penggunaan yang berbeda. Operator aritmatika digunakan untuk melakukan perhitungan, operator perbandingan untuk membandingkan nilai, sedangkan operator logika digunakan untuk menggabungkan beberapa kondisi.
#
# Melalui praktikum ini, praktikan dapat memahami penggunaan dasar berbagai operator dalam Python serta mengetahui bagaimana operator diterapkan dalam sebuah program. Pemahaman mengenai operator sangat penting karena menjadi dasar dalam membuat program yang dapat melakukan perhitungan dan mengambil keputusan berdasarkan kondisi tertentu.
#
# Dengan memahami dan mampu menggunakan operator dengan baik, praktikan akan lebih mudah untuk mempelajari materi Python selanjutnya, seperti percabangan, perulangan, fungsi, dan pengolahan data.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, “Built-in Types,” Python Documentation, 2026. [Online]. Tersedia: https://docs.python.org/3/library/stdtypes.html [Diakses 18 September 2026].
#
# [2] Python Software Foundation, “Expressions — Python 3 Documentation,” Python Documentation, 2026. [Online]. Tersedia: https://docs.python.org/3/reference/expressions.html [Diakses 18 September 2026].
#
# [3] Python Software Foundation, “More Control Flow Tools,” Python Documentation, 2026. [Online]. Tersedia: https://docs.python.org/3/tutorial/controlflow.html [Diakses 18 September 2026].
